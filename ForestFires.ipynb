# %%
#Bradley Wuon Seok Choi
#2nd March 2019
#ISt 652: Scripting for Data Analytics
#MiniProject: Forest Fires in Portugal

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The forest fire data is from the UCI Machine Learning Repository, for more information vist:
# https://archive.ics.uci.edu/ml/datasets/Forest+Fires

# %%
#path of the csv
path = '/Users/wuonseokchoi/Downloads/forestfires.csv'

# %%
#Reading the csv data
ff = pd.read_csv(path, encoding = "latin-1")#encoding = "ISO-8859-1")
ff
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %% [markdown]
# # Attribute Information

# %% [markdown]
# 1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# 2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# 3. month - month of the year: 'jan' to 'dec'
# 4. day - day of the week: 'mon' to 'sun'
# 5. FFMC - Fine Fuel Moisture Code (FFMC) index from the Forest Fire Weather Index (FWI) system: 18.7 to 96.20
# 6. DMC - Duff Moisture Code (DMC) index from the FWI system: 1.1 to 291.3
# 7. DC - Drought Code (DC) index from the FWI system: 7.9 to 860.6
# 8. ISI - Initial Spread Index (ISI) index from the FWI system: 0.0 to 56.10
# 9. temp - temperature in Celsius degrees: 2.2 to 33.30
# 10. RH - relative humidity in %: 15.0 to 100
# 11. wind - wind speed in km/h: 0.40 to 9.40
# 12. rain - outside rain in mm/m2 : 0.0 to 6.4
# 13. area - the burned area of the forest (in ha): 0.00 to 1090.84
# (this output variable is very skewed towards 0.0, thus it may make
# sense to model with the logarithm transform).

# %% [markdown]
# # Cleaning and Formatting the Data

# %%
#Looking at the data type
type(ff)
# Out:
# pandas.core.frame.DataFrame

# %%
#Looking for null values within the data
ff.isnull().values.any()
# Out:
# False

# %%
#Looking at the column names
list(ff.columns.values)
# Out:
# ['X',
#  'Y',
#  'month',
#  'day',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'temp',
#  'RH',
#  'wind',
#  'rain',
#  'area']

# %%
#Looking overall of the data
ff.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
#Looking at the first five rows
ff.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# # Compartive Analysis

# %%
#Calculating correlation 
corr = ff.corr().abs()
fig = plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, cmap = 'Reds')

# %%
corr = pd.DataFrame(corr)
corr
# Out:
#              X         Y      FFMC       DMC        DC       ISI      temp  \
# X     1.000000  0.539548  0.021039  0.048384  0.085916  0.006210  0.051258
# Y     0.539548  1.000000  0.046308  0.007782  0.101178  0.024488  0.024103
# FFMC  0.021039  0.046308  1.000000  0.382619  0.330512  0.531805  0.431532
# DMC   0.048384  0.007782  0.382619  1.000000  0.682192  0.305128  0.469594
# DC    0.085916  0.101178  0.330512  0.682192  1.000000  0.229154  0.496208
# ISI   0.006210  0.024488  0.531805  0.305128  0.229154  1.000000  0.394287
# temp  0.051258  0.024103  0.431532  0.469594  0.496208  0.394287  1.000000
# RH    0.085223  0.062221  0.300995  0.073795  0.039192  0.132517  0.527390
# wind  0.018798  0.020341  0.028485  0.105342  0.203466  0.106826  0.227116
# rain  0.065387  0.033234  0.056702  0.074790  0.035861  0.067668  0.069491
# area  0.063385  0.044873  0.040122  0.072994  0.049383  0.008258  0.097844
#
#             RH      wind      rain      area
# ...

# %%
#Counting the occurrences by month
months = ff.month.value_counts()
print(months)
# Out:
# aug    184
# sep    172
# mar     54
# jul     32
# feb     20
# jun     17
# oct     15
# dec      9
# apr      9
# may      2
# jan      2
# nov      1
# Name: month, dtype: int64

# %%
#storing the results into a pandas dataframe
b = pd.DataFrame({'month':list(months.index),'count': months})
b
# Out:
#     month  count
# aug   aug    184
# sep   sep    172
# mar   mar     54
# jul   jul     32
# feb   feb     20
# jun   jun     17
# oct   oct     15
# dec   dec      9
# apr   apr      9
# may   may      2
# jan   jan      2
# nov   nov      1

# %%
#Comparison of fires by month
g = sns.catplot(x='temp',
                  y='RH',
                  data=ff,
                  hue='month',
                  col='month',
                  kind='swarm')
#Rotating the labels on the x-axis
g.set_xticklabels(rotation=-45)
